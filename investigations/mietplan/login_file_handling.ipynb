# %%
import requests

# %%
login_csrf_url = "https://mietplan-dresden.de/login/"

# %%
from bs4 import BeautifulSoup

def extract_csrf_token(html: str) -> str:
    soup = BeautifulSoup(html, "html.parser")

    # Find the hidden input field containing the CSRF token
    input_element = soup.find("input", {"name": "csrf"})
    if input_element is None:
        raise ValueError("No login form found for csrf token")

    csrf_token = input_element["value"] # type: ignore

    if not csrf_token:
        raise ValueError("Empty CSRF token found in the login form")


    return str(csrf_token)

# %%
def fetch_csrf_token(session: requests.Session) -> str:
    response = session.get(login_csrf_url)
    response.raise_for_status()
    return extract_csrf_token(response.content.decode(encoding='latin-1'))

# %%
from pathlib import Path
import json


credentials = json.load(Path("mietplan_credentials.json").open())

# %%
def login(session: requests.Session, username: str, password: str) -> None:
    csrf_token = fetch_csrf_token(session)

    login_url = "https://mietplan-dresden.de/auctores/scs/auctores.controller.web.InfoLoginMultiController"

    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Language": "de-DE,de;q=0.9,en-US;q=0.8,en-DE;q=0.7,en;q=0.6",
        "Cache-Control": "max-age=0",
        "Origin": "https://mietplan-dresden.de",
        "Referer": "https://mietplan-dresden.de/login/",
        "DNT": "1",
        "Sec-CH-UA": '"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
        "Sec-CH-UA-Mobile": "?0",
        "Sec-CH-UA-Platform": '"Windows"',
        "Sec-Fetch-Dest": "document",
        "Sec-Fetch-Mode": "navigate",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-User": "?1",
        "Upgrade-Insecure-Requests": "1",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
    }

    # Form data
    data = {
        "csrf": csrf_token,  # Dynamically extracted
        "fdInf_ID": "CY25277299X1116e405343XY7477",
        "fdCtrlType": "FORWARDER",
        "fdMode": "MODE_LOGIN",
        "dbUserID": username,
        "dbPasswort": password,
    }

    response = session.post(login_url, headers=headers, data=data)

    response.raise_for_status()

# %%
session = requests.Session()

username = credentials["username"]
password = credentials["password"]
login(session, username, password)

# %%
webdepot_url = "https://mietplan-dresden.de/webdepot/"

response = session.get(webdepot_url)

# %%
class FolderMetadata:
    name: str
    folder_id: str
    has_subfolders: bool

    @staticmethod
    def from_json(json_data: dict) -> 'FolderMetadata':
        metadata = FolderMetadata()

        metadata.name = json_data["filename"]
        metadata.folder_id = json_data["fileid"]
        metadata.has_subfolders = json_data["filechildren"]

        return metadata

    def __repr__(self) -> str:
        return f"FolderMetadata(name={self.name}, folder_id={self.folder_id}, has_subfolders={self.has_subfolders})"

# %%
def get_folders(session: requests.Session, parent_folder_id: str) -> list[FolderMetadata ]:
    main_folder_url = f"https://mietplan-dresden.de/moxanos/json?&svc=org.auctores.bvi.mietplan2&msg=getFolders&fdFolder={parent_folder_id}"

    response = session.get(main_folder_url)
    response.raise_for_status()

    folders = [FolderMetadata.from_json(folder_json) for folder_json in response.json().values()]

    return folders

main_folder_id = "ac4do35ktgfi79j8ids35om8udm"

folders = get_folders(session, main_folder_id)

# %%
file_url = "https://mietplan-dresden.de/moxanos/json?&svc=org.auctores.bvi.mietplan2&msg=getFiles&fdFolder=aq00vmb30jvhql0fp04sdog4m3b"

response = session.get(file_url)

# %%
response.json()
# Out:
# {'22': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a70u1smb38fl73prjb08la6m294/2008-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '948 KB',
#   'filename': '2008-07 BP.pdf',
#   'filepath': '/download/a70u1smb38fl73prjb08la6m294/2008-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aa8nm24nnfqngpc74ttineklfnq'},
#  '23': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aq6svg7i4odden8cjavlbstms9l/2009-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2009-07 BP.pdf',
#   'filepath': '/download/aq6svg7i4odden8cjavlbstms9l/2009-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'atuhh5qkkttemvfoun7e4ns3gp'},
#  '24': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/acvaan6fkr8qjv7f94lkj44elao/2010-08 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2010-08 BP.pdf',
#   'filepath': '/download/acvaan6fkr8qjv7f94lkj44elao/2010-08 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'an6s9ebu6isq8h5n2v1tsaiabjm'},
#  '25': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aamgrtia395dgjiia9fo431qtrv/2011-10 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '896 KB',
#   'filename': '2011-10 BP.pdf',
#   'filepath': '/download/aamgrtia395dgjiia9fo431qtrv/2011-10 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'ajq40gi15ja2q3pfog0a7erpdvp'},
#  '26': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/auc7tcv9j908ojknrl7tvg9ns/1997-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '219 KB',
#   'filename': '1997-09 BP.pdf',
#   'filepath': '/download/auc7tcv9j908ojknrl7tvg9ns/1997-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'acgl4i08tuu0pon0lclc4d6e6ai'},
#  '27': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/amlt9kig9jdpef5pegt7jjpa5q/1998-11 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '434 KB',
#   'filename': '1998-11 BP.pdf',
#   'filepath': '/download/amlt9kig9jdpef5pegt7jjpa5q/1998-11 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aahu568q00f1ubn3r29vvscq5qb'},
#  '28': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/auhlehfmp09u9oauo4kc8p0d736/1999-10 BP TG.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '353 KB',
#   'filename': '1999-10 BP TG.pdf',
#   'filepath': '/download/auhlehfmp09u9oauo4kc8p0d736/1999-10 BP TG.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'arv88c2o1fhat5sepifve44p3q6'},
#  '29': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aui79ac7n8trie9hrs9ii5btf1h/1999-10 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '301 KB',
#   'filename': '1999-10 BP.pdf',
#   'filepath': '/download/aui79ac7n8trie9hrs9ii5btf1h/1999-10 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a6u8lnn6hvssh726ircf89bq92g'},
#  '30': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/ag80uq658knqb1rs3b029hduvcc/2000-05 ao ETV.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '269 KB',
#   'filename': '2000-05 ao ETV.pdf',
#   'filepath': '/download/ag80uq658knqb1rs3b029hduvcc/2000-05 ao ETV.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a2nhu2fgasr12m0cud9k3cneec3'},
#  '31': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/alj1417hob52eglvn0tv52pj5l7/2000-07 ao ETV.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '146 KB',
#   'filename': '2000-07 ao ETV.pdf',
#   'filepath': '/download/alj1417hob52eglvn0tv52pj5l7/2000-07 ao ETV.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a5m48etvqdph77njm6hvrgdu300'},
#  '10': {'filechildren': True,
#   'filechan': '17.10.2017',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aos9dnqvpig2qqi52sk75olj0hs/2017-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '814 KB',
#   'filename': '2017-09 BP.pdf',
#   'filepath': '/download/aos9dnqvpig2qqi52sk75olj0hs/2017-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'auh71ba5no30o2mu2fb2nju1le2'},
#  '32': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aqr56cjkqic1195ag3k11c6msbk/2000-10 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '560 KB',
#   'filename': '2000-10 BP.pdf',
#   'filepath': '/download/aqr56cjkqic1195ag3k11c6msbk/2000-10 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a263oj5bg4qqlggvl7muvbb4d6a'},
#  '11': {'filechildren': True,
#   'filechan': '14.12.2016',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a4hqke3m48abdcgh44qfi035qte/2016-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '108 KB',
#   'filename': '2016-09 BP.pdf',
#   'filepath': '/download/a4hqke3m48abdcgh44qfi035qte/2016-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aarc5s8h47bn8oqtsgq8tcpaf0p'},
#  '33': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/am90rmgs8jtbdfcnrspd694ptih/2001-03 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '733 KB',
#   'filename': '2001-03 BP.pdf',
#   'filepath': '/download/am90rmgs8jtbdfcnrspd694ptih/2001-03 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'arscebat8t9oocaisd8li4qepgv'},
#  '12': {'filechildren': True,
#   'filechan': '14.12.2016',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a6o4dudu8musnmmpiq5qalpust7/2016-10 BP Wiederholungsversammlung.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2016-10 BP Wiederholungsversammlung.pdf',
#   'filepath': '/download/a6o4dudu8musnmmpiq5qalpust7/2016-10 BP Wiederholungsversammlung.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'augt7eke4jn4glbr7obcnutou3o'},
#  '34': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aal5ko7pmjcq8nib9s7imhfamm9/2002-10 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '867 KB',
#   'filename': '2002-10 BP.pdf',
#   'filepath': '/download/aal5ko7pmjcq8nib9s7imhfamm9/2002-10 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aa2ekv9525n20i1h33f4gr8e7ic'},
#  '13': {'filechildren': True,
#   'filechan': '22.09.2015',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/askluln56t9jlsuafst8p4llcfh/2015-08 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2015-08 BP.pdf',
#   'filepath': '/download/askluln56t9jlsuafst8p4llcfh/2015-08 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'ack5r6agk33aqsvqt62vts51q1j'},
#  '35': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a1ctvbm32519dbt6epa844bog3i/2003-04 ao EVT.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '268 KB',
#   'filename': '2003-04 ao EVT.pdf',
#   'filepath': '/download/a1ctvbm32519dbt6epa844bog3i/2003-04 ao EVT.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a6s25qrfois5pq9qnhatseqkrcr'},
#  '14': {'filechildren': True,
#   'filechan': '19.05.2015',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a7uvvbbfmegvd9focn8hdq9eolb/2005-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2005-09 BP.pdf',
#   'filepath': '/download/a7uvvbbfmegvd9focn8hdq9eolb/2005-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'api1fe0rabfl0ju4v4tvj1uqisg'},
#  '36': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/apeogn7el0il4t7kiq8hia194r5/2003-11 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '949 KB',
#   'filename': '2003-11 BP.pdf',
#   'filepath': '/download/apeogn7el0il4t7kiq8hia194r5/2003-11 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'atk1ormvqe2ugknbl5vb1ljplog'},
#  '15': {'filechildren': True,
#   'filechan': '17.09.2014',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/acufnl133n57a2250bg1ou75qkf/2014-08 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '760 KB',
#   'filename': '2014-08 BP.pdf',
#   'filepath': '/download/acufnl133n57a2250bg1ou75qkf/2014-08 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'ashjun3ht9kqrra80tvok6j98qm'},
#  '37': {'filechildren': True,
#   'filechan': '01.06.2010',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aa03l9n80pcbmml438nqeftscrb/2004-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2004-09 BP.pdf',
#   'filepath': '/download/aa03l9n80pcbmml438nqeftscrb/2004-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'am1lsvfb2bijf5ev4riuk68rjt0'},
#  '16': {'filechildren': True,
#   'filechan': '19.12.2013',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a4bc2l07c7p0ramn3gqbbco3ol0/2013-09 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2013-09 BP.pdf',
#   'filepath': '/download/a4bc2l07c7p0ramn3gqbbco3ol0/2013-09 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'annl6jn7nn5565p40c6777cl5gm'},
#  '17': {'filechildren': True,
#   'filechan': '13.11.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aoqm40lvub4thlvfpj78uonfpod/2012-08 BP ao ETV.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '482 KB',
#   'filename': '2012-08 BP ao ETV.pdf',
#   'filepath': '/download/aoqm40lvub4thlvfpj78uonfpod/2012-08 BP ao ETV.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'anok6qv0eh52t22sps0vjjcf38r'},
#  '18': {'filechildren': True,
#   'filechan': '11.07.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/at41knpeo7b903o1p380nl5kk7n/2012-06 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '978 KB',
#   'filename': '2012-06 BP.pdf',
#   'filepath': '/download/at41knpeo7b903o1p380nl5kk7n/2012-06 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'ahbivpospch7baao7cldemjo430'},
#  '19': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/asif1t59qm955tshe2v7bthqia9/2006-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '96 KB',
#   'filename': '2006-07 BP.pdf',
#   'filepath': '/download/asif1t59qm955tshe2v7bthqia9/2006-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aabcq1028p1sdci9rstbq5fvboc'},
#  '0': {'filechildren': True,
#   'filechan': '18.10.2024',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aqibpfrlj4ffbrc4mcres461jae/2024-10 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '18.10.2024',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2024-10 BP.pdf',
#   'filepath': '/download/aqibpfrlj4ffbrc4mcres461jae/2024-10 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'ai44kopljolfq7s1thq8l9mpc5q'},
#  '1': {'filechildren': True,
#   'filechan': '15.07.2024',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/atl0pht9mucjua7ql1sgjcso8rt/2024-06 BP ao ETV.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '15.07.2024',
#   'filebdir': 'false',
#   'filesize': '399 KB',
#   'filename': '2024-06 BP ao ETV.pdf',
#   'filepath': '/download/atl0pht9mucjua7ql1sgjcso8rt/2024-06 BP ao ETV.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'acgd5g2ks5rd1n224mrch66hcln'},
#  '2': {'filechildren': True,
#   'filechan': '22.01.2024',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/anb4dvdhtgjrp8lce97ecge3ebl/2023-12 BP ao ETV.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '22.01.2024',
#   'filebdir': 'false',
#   'filesize': '527 KB',
#   'filename': '2023-12 BP ao ETV.pdf',
#   'filepath': '/download/anb4dvdhtgjrp8lce97ecge3ebl/2023-12 BP ao ETV.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'arm5anbgcjj6q511bp8354uv4mb'},
#  '3': {'filechildren': True,
#   'filechan': '06.12.2023',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/ac515b6j1u7ko7vos3pm4g6a126/Beschlussbuch.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '06.12.2023',
#   'filebdir': 'false',
#   'filesize': '280 KB',
#   'filename': 'Beschlussbuch.pdf',
#   'filepath': '/download/ac515b6j1u7ko7vos3pm4g6a126/Beschlussbuch.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aq2k6eav16g8ckl6ic9h5qdeg8s'},
#  '4': {'filechildren': True,
#   'filechan': '30.08.2023',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/atq8o5rfpjjp950u1i1g3uv6mv7/2023-08 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '30.08.2023',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2023-08 BP.pdf',
#   'filepath': '/download/atq8o5rfpjjp950u1i1g3uv6mv7/2023-08 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a2n6jsh0bcba1qu1upltdmi5i0b'},
#  '5': {'filechildren': True,
#   'filechan': '20.07.2022',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a5fu6gamb98suimivk607jkj4vo/2022-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '20.07.2022',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2022-07 BP.pdf',
#   'filepath': '/download/a5fu6gamb98suimivk607jkj4vo/2022-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a3khlnc8vm4agur085glmhk4l9l'},
#  '6': {'filechildren': True,
#   'filechan': '04.08.2021',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a9len91dspo8h91au8e0m698eng/2021-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.08.2021',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2021-07 BP.pdf',
#   'filepath': '/download/a9len91dspo8h91au8e0m698eng/2021-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'aej4tap69tvpbghnnp9b857so96'},
#  '7': {'filechildren': True,
#   'filechan': '23.07.2020',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/ac45016nvuqd135fncerd9hj31n/2020-07 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '23.07.2020',
#   'filebdir': 'false',
#   'filesize': '995 KB',
#   'filename': '2020-07 BP.pdf',
#   'filepath': '/download/ac45016nvuqd135fncerd9hj31n/2020-07 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a2pgpu2s8j5i1p0nhfan6d63ll3'},
#  '8': {'filechildren': True,
#   'filechan': '02.07.2019',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aagu1vk9di0el9kr7keucsm166r/2019-06 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2019-06 BP.pdf',
#   'filepath': '/download/aagu1vk9di0el9kr7keucsm166r/2019-06 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a9b8sh1b5r19dug4givspf4id66'},
#  '9': {'filechildren': True,
#   'filechan': '18.07.2018',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/akdsp2c54nq8h1pu7f5ipi0bvje/2018-06 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '809 KB',
#   'filename': '2018-06 BP.pdf',
#   'filepath': '/download/akdsp2c54nq8h1pu7f5ipi0bvje/2018-06 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'atisf0nd1rksgtgsmg46c7dom53'},
#  '20': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/a310hnmi02bj4gq395ckhlrh655/2006-08 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2006-08 BP.pdf',
#   'filepath': '/download/a310hnmi02bj4gq395ckhlrh655/2006-08 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'auiudqfjom05ag50tblths2oevr'},
#  '21': {'filechildren': True,
#   'filechan': '21.03.2012',
#   'filedesc': '',
#   'file_dl': [{'filepath': '/download/aaaa4pukfb9n86uqop21kc4mf4k/2007-06 BP.pdf',
#     'dl_name': 'Datei'}],
#   'GENFLD_D67E08BADX130315CD094XY770E': '',
#   'filecrea': '04.06.2020',
#   'filebdir': 'false',
#   'filesize': '1 MB',
#   'filename': '2007-06 BP.pdf',
#   'filepath': '/download/aaaa4pukfb9n86uqop21kc4mf4k/2007-06 BP.pdf',
#   'filealias': 'BMT_DATEI',
#   'filekeywords': '',
#   'filenext': 'pdf',
#   'fileid': 'a1omib9r60ujq88tiagvnscvdhc'}}

# %%
from datetime import datetime


class FileMetadata:
    creation_date: datetime
    download_path: str
    filename: str

    @staticmethod
    def from_json(json_data: dict) -> 'FileMetadata':
        metadata = FileMetadata()

        date_format = "%d.%m.%Y"
        metadata.creation_date = datetime.strptime(json_data["filecrea"], date_format)
        metadata.download_path = json_data["filepath"]
        metadata.filename = metadata.download_path.split("/")[-1]

        return metadata

    def __repr__(self) -> str:
        return f"FileMetadata(creation_date={self.creation_date}, download_path={self.download_path}, filename={self.filename})"

def get_files(session: requests.Session, folder_id: str) -> list[FileMetadata]:
    file_url = f"https://mietplan-dresden.de/moxanos/json?&svc=org.auctores.bvi.mietplan2&msg=getFiles&fdFolder={folder_id}"

    response = session.get(file_url)
    response.raise_for_status()

    files = [FileMetadata.from_json(file_json) for file_json in response.json().values()]

    return files

# %%
some_folder_id = folders[1].folder_id
files = get_files(session, some_folder_id)
files
# Out:
# [FileMetadata(creation_date=2024-09-05 00:00:00, download_path=/download/avfkmj4qelgh2jif884i1celf15/2023 Bod25-25a, B&ouml;1, GW2.pdf, filename=2023 Bod25-25a, B&ouml;1, GW2.pdf),
#  FileMetadata(creation_date=2023-06-28 00:00:00, download_path=/download/apenpshuo4kmfb1rqb1imgqj7ve/2022 Bod25-25a, B&ouml;1, GW2.pdf, filename=2022 Bod25-25a, B&ouml;1, GW2.pdf)]

# %%
import html

download_path = html.unescape(files[0].download_path)
print(f"Download path: {download_path}")
# Out:
# Download path: /download/avfkmj4qelgh2jif884i1celf15/2023 Bod25-25a, Bö1, GW2.pdf

# %%
def download_file(session: requests.Session, download_path: str) -> None:
    download_base = "https://mietplan-dresden.de"
    download_url = download_base + download_path

    # download file from download_url
    response = session.get(download_url)

    # save file to disk
    filename = download_url.split("/")[-1]
    with open(filename, "wb") as file:
        file.write(response.content)
