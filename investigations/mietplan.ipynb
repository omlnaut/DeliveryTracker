# %%
import requests

# %%
login_url = "https://mietplan-dresden.de/login/"

# %%
response = requests.get(login_url)

html = response.content.decode(encoding='latin-1')
html
# Out:
# '<!DOCTYPE HTML>\r\n<html  lang="de-DE">\r\n<head>\r\n   <title>Login  | Mietplan GmbH in Dresden</title>\r\n   <meta http-equiv="content-type" content="text/html; charset=ISO-8859-1">\r\n   <meta name="Robots" content="index,follow">\r\n   <meta name="description" content="Login  | Mietplan GmbH in Dresden">\r\n   <meta name="generator" content="auctores CMS">\r\n   <meta name="author" content="Mietplan GmbH">\r\n\r\n\r\n   <meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n   <meta id="mobileviewport" name="viewport" content="width=device-width, initial-scale=1">\n\r\n\r\n   <link rel="canonical" href="https://mietplan-dresden.de/login/">\r\n\r\n      <style nonce="aignakbv9ubmr1k3ole27hmc7ak" type="text/css"  class="acWebfont">@font-face { font-family: \'Open Sans\'; font-display: swap; font-style: normal; font-weight: 300; src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.eot\'); src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.eot?#iefix\') format(\'embedded-opentype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.woff2\') format(\'woff2\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.woff\') format(\'woff\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.ttf\') format(\'truetype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-300.svg#OpenSans\') format(\'truetype\'); }@font-face { font-family: \'Open Sans\'; font-display: swap; font-style: normal; font-weight: 400; src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.eot\'); src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.eot?#iefix\') format(\'embedded-opentype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.woff2\') format(\'woff2\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.woff\') format(\'woff\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.ttf\') format(\'truetype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-regular.svg#OpenSans\') format(\'truetype\'); }@font-face { font-family: \'Open Sans\'; font-display: swap; font-style: normal; font-weight: 700; src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.eot\'); src: url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.eot?#iefix\') format(\'embedded-opentype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.woff2\') format(\'woff2\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.woff\') format(\'woff\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.ttf\') format(\'truetype\'), url(\'/org.auctores.auctoresfont/org/auctores/auctoresfont/view/jsp/fonts/open-sans-v15-latin-700.svg#OpenSans\') format(\'truetype\'); }</style>\r\n\r\n      <link nonce="aignakbv9ubmr1k3ole27hmc7ak" rel="stylesheet" type="text/css" href="/org.dreamox.cmsmox.divlayout/static/1739198418611/css/fancybox/jquery.fancybox.css">\r\n   <link nonce="aignakbv9ubmr1k3ole27hmc7ak" rel="stylesheet" type="text/css" href="/org.dreamox.cms.appmenu/static/1739198427423/css/default.css">\r\n\r\n   <link nonce="aignakbv9ubmr1k3ole27hmc7ak" id="precompiledLessStyle" rel="stylesheet" type="text/css" href="/download/akiek8kstue940g2h3nto5855g2/less-0-1739287284365.css">\r\n      <script nonce="aignakbv9ubmr1k3ole27hmc7ak" type="text/javascript" src="/org.dreamo ...

# %%
"csrf" in html.lower()
# Out:
# True

# %%
from bs4 import BeautifulSoup

def extract_csrf_token(html: str) -> str:
    soup = BeautifulSoup(html, "html.parser")

    # Find the hidden input field containing the CSRF token
    input_element = soup.find("input", {"name": "csrf"})
    if input_element is None:
        raise ValueError("No login form found for csrf token")

    csrf_token = input_element["value"] # type: ignore

    if not csrf_token:
        raise ValueError("Empty CSRF token found in the login form")


    return str(csrf_token)

csrf_token_value = extract_csrf_token(html)
csrf_token_value
# Out:
# '1d39167c70b04832e8e7a74bef5d1bb39eecc2f9'

# %%
def fetch_csrf_token() -> str:
    response = requests.get(login_url)
    response.raise_for_status()
    return extract_csrf_token(response.content.decode(encoding='latin-1'))
